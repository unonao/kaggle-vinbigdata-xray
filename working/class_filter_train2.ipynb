# %% [markdown]
# # Colab or Kaggle

# %%
#ColaboratoryかKaggleNotebookか判別
import sys
import os
from pathlib import Path

MAIN_INPUT_NAME = "vinbigdata-512-image-dataset"
MAIN_INPUT_ZIP = f'../input/{MAIN_INPUT_NAME}.zip'


if 'google.colab' in sys.modules:  # colab環境
    INPUT = Path('/content/input/')

    # drive mount
    from google.colab import drive
    drive.mount('/content/drive/')

    # working dir に移動
    os.chdir('drive/MyDrive/git/kaggle-vinbigdata-xray/working')
    print("cwd:", os.getcwd())

    # 必要な input を指定先へ unzip
    # !unzip -q {MAIN_INPUT_ZIP} -d {INPUT}
    print("unzip INPUT")
    
elif 'kaggle_web_client' in sys.modules:  # kaggle環境
    INPUT = Path('../input/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b100d4c68ede> in <module>()
#      16
#      17     # working dir に移動
# ---> 18     os.chdir('drive/MyDrive/git/kaggle-vinbigdata-xray/working')
#      19     print("cwd:", os.getcwd())
#      20
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/git/kaggle-vinbigdata-xray/working'

# %% [markdown]
# # W&BとCFG

# %%
# W&B
# !pip install wandb -qqq
import wandb
# !wandb login

wandb.init(
    project="vinbigdata-class-filter", 
)
# Out:
# wandb: Currently logged in as: kami (use `wandb login --relogin` to force relogin)
# Finishing last run (ID:1fgz7i7j) before initializing another...
# <br/>Waiting for W&B process to finish, PID 479<br/>Program ended successfully.
# VBox(children=(Label(value=' 4.39MB of 4.39MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/drive/My Drive/git/kaggle-vinbigdata-xray/working/wandb/run-20210327_021258-1fgz7i7j/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/git/kaggle-vinbigdata-xray/working/wandb/run-20210327_021258-1fgz7i7j/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>avg_train_loss</td><td>0.01162</td></tr><tr><td>avg_val_loss</td><td>0.14614</td></tr><tr><td>val_accuracy</td><td>0.96</td></tr><tr><td>val_roc_auc</td><td>0.94368</td></tr><tr><td>val_f1</td><td>0.97204</td></tr><tr><td>_runtime</td><td>6750</td></tr><tr><td>_timestamp</td><td>1616817928</td></tr><tr><td>_step</td><td>7</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>avg_train_loss</td><td>█▅▄▃▂▂▁▁</td></tr><tr><td>avg_val_loss</td><td>█▂▁▂▄▄▆▆</td></tr><tr><td>val_accuracy</td><td>▁▆█▇▆▇▇▇</td></tr><tr><td>val_roc_auc</td><td>▁▇████▇▇</td></tr><tr><td>val_f1</td><td>▁▆█▇▆▇▇▇</td></tr><tr><td>_runtime</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>_timestamp</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>_step</td><td>▁▂▃▄▅▆▇█</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">2021.03.27.02.12</strong>: <a href="https://wandb.ai/kami/vinbigdata-class-filter/runs/1fgz7i7j" target="_blank">https://wandb.ai/kami/vinbigdata-class-filter/runs/1fgz7i7j</a><br/>
# ...Successfully finished last run (ID:1fgz7i7j). Initializing new run:<br/><br/>
#                 Tracking run with wandb version 0.10.23<br/>
#                 Syncing run <strong style="color:#cdcd00">clear-lion-12</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/kami/vinbigdata-class-filter" target="_blank">https://wandb.ai/kami/vinbigdata-class-filter</a><br/>
#                 Run page: <a href="https://wandb.ai/kami/vinbigdata-class-filter/runs/1sx5pcel" target="_blank">https://wandb.ai/kami/vinbigdata-class-filter/runs/1sx5pcel</a><br/>
#                 Run data is saved locally in <code>/content/drive/My Drive/git/kaggle-vinbigdata-xray/working/wandb/run-20210327_041740-1sx5pcel</code><br/><br/>
# <h1>Run(1sx5pcel)</h1><iframe src="https://wandb.ai/kami/vinbigdata-class-filter/runs/1sx5pcel" style="border:none;width:100%;height:400px"></iframe>

# %%
# configの設定
CFG={
    "learning_rate": 0.02,
    # "dropout": 0.2,
    "debug": False, 
    "apex":False,
    "print_freq":100,
    "num_workers": 2,
    "architecture": "efficientnet", # ["efficientnet", "vit", "resnet"]
    "model_name": 'tf_efficientnet_b5_ns',
    "size": 456,
    "scheduler": 'CosineAnnealingWarmRestarts', # ['ReduceLROnPlateau', 'CosineAnnealingLR', 'CosineAnnealingWarmRestarts']
    "epochs": 10,
    #factor=0.2 # ReduceLROnPlateau
    #patience=4 # ReduceLROnPlateau
    #eps=1e-6 # ReduceLROnPlateau
    #T_max=10 # CosineAnnealingLR
    "T_0": 10, # CosineAnnealingWarmRestarts
    "lr":3e-5,
    "min_lr":3e-7,
    "batch_size":8,
    "weight_decay":1e-6,
    "gradient_accumulation_steps":1,
    "max_grad_norm":1000,
    "seed":42,
    "target_size":2,
    "target_col":'label',
    "n_fold":5,
    "trn_fold":[0], # [0, 1, 2, 3, 4], (n_fold:5) 実験では fold 0 のみで十分
    "train":True,
    "inference":False,
  }


#-----------------------------------
# for wandb
#-----------------------------------
# config
wandb.config.update(CFG)
# run name
import datetime
now = datetime.datetime.now()
wandb.run.name = CFG["model_name"] +"_" + now.strftime('%Y.%m.%d.%H.%M') 
# tag
wandb.run.tags = [CFG["architecture"]]

# %% [markdown]
# # Data Loading

# %%
import os

import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %%
os.listdir(os.path.join(INPUT, MAIN_INPUT_NAME, "vinbigdata"))
# Out:
# ['test', 'train.csv', 'test.csv', 'sample_submission.csv', 'train']

# %%
train = pd.read_csv(os.path.join(INPUT, MAIN_INPUT_NAME, "vinbigdata","train.csv"))
train = train.groupby("image_id")["class_id"].agg(lambda s: (s == 14).sum()).reset_index().rename({"class_id": "num_normal_annotations"}, axis=1)
train["label"] = (train["num_normal_annotations"] == 3).astype(int)  # 3人とも異常なしを1とする

test = pd.read_csv(os.path.join(INPUT, MAIN_INPUT_NAME, "vinbigdata","sample_submission.csv"))

display(train.head())
display(test.head())
# Out:
#                            image_id  num_normal_annotations  label
# 0  000434271f63a053c4128a0ba6352c7f                       3      1
# 1  00053190460d56c53cc3e57321387478                       3      1
# 2  0005e8e3701dfb1dd93d53e2ff537b6e                       0      0
# 3  0006e0a85696f6bb578e84fafa9a5607                       3      1
# 4  0007d316f756b3fa0baea2ff514ce945                       0      0
#                            image_id PredictionString
# 0  002a34c58c5b758217ed1f584ccbcfe9     14 1 0 0 1 1
# 1  004f33259ee4aef671c2b95d54e4be68     14 1 0 0 1 1
# 2  008bdde2af2462e86fd373a445d0f4cd     14 1 0 0 1 1
# 3  009bc039326338823ca3aa84381f17f1     14 1 0 0 1 1
# 4  00a2145de1886cb9eb88869c85d74080     14 1 0 0 1 1

# %%
if CFG["debug"]:
    CFG["epochs"] = 1
    train = train.sample(n=1000, random_state=CFG["seed"]).reset_index(drop=True)

# %%
sns.distplot(train['label'], kde=False)

# %% [markdown]
# # Directory settings

# %%
# ====================================================
# Directory settings
# ====================================================
import os

OUTPUT_DIR = './output'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

TRAIN_PATH = os.path.join(INPUT, MAIN_INPUT_NAME, "vinbigdata","train")
TEST_PATH = os.path.join(INPUT, MAIN_INPUT_NAME, "vinbigdata","test")

# %% [markdown]
# # Library

# %%
# !pip install -U albumentations
# !pip install timm
# Out:
# Requirement already up-to-date: albumentations in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied, skipping upgrade: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (4.5.1.48)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.19.5)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.16.1 in /usr/local/lib/python3.7/dist-packages (from albumentations) (0.16.2)
# Requirement already satisfied, skipping upgrade: PyYAML in /usr/local/lib/python3.7/dist-packages (from albumentations) (3.13)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.7/dist-packages (from albumentations) (1.4.1)
# Requirement already satisfied, skipping upgrade: imgaug>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from albumentations) (0.4.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.4.1)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (1.1.1)
# Requirement already satisfied, skipping upgrade: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (3.2.2)
# Requirement already satisfied, skipping upgrade: pillow>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (7.0.0)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image>=0.16.1->albumentations) (2.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from imgaug>=0.4.0->albumentations) (1.15.0)
# Requirement already satisfied, skipping upgrade: Shapely in /usr/local/lib/python3.7/dist-packages (from imgaug>=0.4.0->albumentations) (1.7.1)
# Requirement already satisfied, skipping upgrade: opencv-python in /usr/local/lib/python3.7/dist-packages (from imgaug>=0.4.0->albumentations) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.8.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (1.3.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (2.4.7)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image>=0.16.1->albumentations) (0.10.0)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from networkx>=2.0->scikit-image>=0.16.1->albumentations) (4.4.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.7/dist-packages (0.4.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.9.0+cu101)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.8.0+cu101)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (3.7.4.3)

# %%
# ====================================================
# Library
# ====================================================

import sys
import os
import math
import time
import random
import shutil
from pathlib import Path
from contextlib import contextmanager
from collections import defaultdict, Counter

import scipy as sp
import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score
from sklearn.model_selection import StratifiedKFold

from tqdm.auto import tqdm
from functools import partial

import cv2
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, SGD
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, CosineAnnealingLR, ReduceLROnPlateau

from albumentations import (
    Compose, OneOf, Normalize, Resize, RandomResizedCrop, RandomCrop, HorizontalFlip, VerticalFlip, 
    RandomBrightness, RandomContrast, RandomBrightnessContrast, Rotate, ShiftScaleRotate, Cutout, 
    IAAAdditiveGaussianNoise, Transpose
    )
from albumentations.pytorch import ToTensorV2
from albumentations import ImageOnlyTransform

import timm

import warnings 
warnings.filterwarnings('ignore')

if CFG["apex"]:
    from apex import amp

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Utils

# %%
# ====================================================
# Utils
# ====================================================
def get_score(y_true, y_pred):
    return accuracy_score(y_true, y_pred)


@contextmanager
def timer(name):
    t0 = time.time()
    LOGGER.info(f'[{name}] start')
    yield
    LOGGER.info(f'[{name}] done in {time.time() - t0:.0f} s.')


def init_logger(log_file=OUTPUT_DIR+'train.log'):
    from logging import getLogger, INFO, FileHandler,  Formatter,  StreamHandler, shutdown
    logger = getLogger(__name__)
    for h in logger.handlers:
        logger.removeHandler(h)
    logger.setLevel(INFO)
    handler1 = StreamHandler()
    handler1.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler1)
    '''handler2 = FileHandler(filename=log_file)
    handler2.setFormatter(Formatter("%(message)s"))
    logger.addHandler(handler2)'''
    return logger

LOGGER = init_logger()


def seed_torch(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

seed_torch(seed=CFG["seed"])

# %% [markdown]
# # CV split

# %%
folds = train.copy()
Fold = StratifiedKFold(n_splits=CFG["n_fold"], shuffle=True, random_state=CFG["seed"])
for n, (train_index, val_index) in enumerate(Fold.split(folds, folds[CFG["target_col"]])):
    folds.loc[val_index, 'fold'] = int(n)
folds['fold'] = folds['fold'].astype(int)
print(folds.groupby(['fold', CFG["target_col"]]).size())
# Out:
# fold  label
# 0     0         878
#       1        2122
# 1     0         879
#       1        2121
# 2     0         879
#       1        2121
# 3     0         879
#       1        2121
# 4     0         879
#       1        2121
# dtype: int64

# %% [markdown]
# # Dataset

# %%
# ====================================================
# Dataset
# ====================================================
class TrainDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values + ".png"
        self.labels = df['label'].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TRAIN_PATH}/{file_name}'
        image = cv2.imread(file_path)
        #iimage = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image'].float()
        label = torch.tensor(self.labels[idx]).long()
        return image, label
    

class TestDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values + ".png"
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TEST_PATH}/{file_name}'
        image = cv2.imread(file_path)
        #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image'].float()
        return image

# %%
# test
train_dataset = TrainDataset(train, transform=None)

for i in range(1):
    image, label = train_dataset[i]
    print(type(image))
    plt.imshow(image)
    plt.title(f'label: {label}')
    plt.show()
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Transforms

# %%
# ====================================================
# Transforms
# ====================================================
def get_transforms(*, data):
    
    if data == 'train':
        return Compose([
            Resize(CFG["size"], CFG["size"]),
            #RandomResizedCrop(CFG["size"], CFG["size"]),
            #Transpose(p=0.5),
            HorizontalFlip(p=0.5),
            ShiftScaleRotate(scale_limit=0.05, rotate_limit=5, p=0.5),
            Cutout(p=0.5),
            #VerticalFlip(p=0.5),
            #ShiftScaleRotate(p=0.5),
            #Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],),
            ToTensorV2(p=1.0),
        ], p=1.)

    elif data == 'valid':
        return Compose([
            Resize(CFG["size"], CFG["size"]),
            #Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225],  ),
            ToTensorV2(p=1.0),
        ], p=1.)

# %%
# test
train_dataset = TrainDataset(train, transform=get_transforms(data='train'))

for i in range(1):
    image, label = train_dataset[i]
    plt.imshow(image[0])
    plt.title(f'label: {label}')
    plt.show()

# %% [markdown]
# # MODEL

# %%
# ====================================================
# MODEL
# ====================================================
class XrayImgClassifierEfficientnet(nn.Module):
    def __init__(self, model_name='efficientnet_b0', pretrained=False):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)
        n_features = self.model.classifier.in_features
        self.model.classifier = nn.Linear(n_features, CFG["target_size"])
    def forward(self, x):
        x = self.model(x)
        return x
class XrayImgClassifierVit(nn.Module):
    def __init__(self, model_name='vit_base_patch16_224',  pretrained=True):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)
        n_features = self.model.head.in_features
        self.model.head = nn.Linear(n_features, CFG["target_size"])
    def forward(self, x):
        x = self.model(x)
        return x
class XrayImgClassifierResNext(nn.Module):
    def __init__(self, model_name='resnext50_32x4d', pretrained=False):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)
        n_features = self.model.fc.in_features
        self.model.fc = nn.Linear(n_features, CFG["target_size"])

    def forward(self, x):
        x = self.model(x)
        return x

def get_model(pretrained=False):
    if CFG["architecture"] == "efficientnet":
      model = XrayImgClassifierEfficientnet(model_name=CFG["model_name"], pretrained=pretrained)
    elif CFG["architecture"] == "vit":
      model = XrayImgClassifierVit(model_name=CFG["model_name"], pretrained=pretrained)
    elif CFG["architecture"] == "resnet":
      model = XrayImgClassifierResNext(model_name=CFG["model_name"], pretrained=pretrained)
    return model

# %%
# test
model = get_model()

train_dataset = TrainDataset(train, transform=get_transforms(data='train'))
train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True,
                          num_workers=4, pin_memory=True, drop_last=True)

for image, label in train_loader:
    print(image.shape)
    output = model(image)
    print(output)
    break
# Out:
# torch.Size([4, 3, 456, 456])
# tensor([[ 0.0316,  0.0276],
#         [-0.3166,  0.1417],
#         [ 0.0279,  0.0268],
#         [-0.4093,  0.1729]], grad_fn=<AddmmBackward>)

# %% [markdown]
# # Helper functions

# %%
# ====================================================
# Helper functions
# ====================================================
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))


def train_fn(train_loader, model, criterion, optimizer, epoch, scheduler, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to train mode
    model.train()
    start = end = time.time()
    global_step = 0
    for step, (images, labels) in enumerate(train_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        y_preds = model(images)
        loss = criterion(y_preds, labels)
        # record loss
        losses.update(loss.item(), batch_size)
        if CFG["gradient_accumulation_steps"] > 1:
            loss = loss / CFG["gradient_accumulation_steps"]
        if CFG["apex"]:
            with amp.scale_loss(loss, optimizer) as scaled_loss:
                scaled_loss.backward()
        else:
            loss.backward()
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG["max_grad_norm"])
        if (step + 1) % CFG["gradient_accumulation_steps"] == 0:
            optimizer.step()
            optimizer.zero_grad()
            global_step += 1
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG["print_freq"] == 0 or step == (len(train_loader)-1):
            LOGGER.info('Epoch(train): [{0}][{1}/{2}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  'Grad: {grad_norm:.4f}  '
                  #'LR: {lr:.6f}  '
                  .format(
                   epoch+1, step, len(train_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(train_loader)),
                   grad_norm=grad_norm,
                   #lr=scheduler.get_lr()[0],
                   ))
    return losses.avg


def valid_fn(valid_loader, model, criterion, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    # switch to evaluation mode
    model.eval()
    preds = []
    start = end = time.time()
    for step, (images, labels) in enumerate(valid_loader):
        # measure data loading time
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        # compute loss
        with torch.no_grad():
            y_preds = model(images)
        loss = criterion(y_preds, labels)
        losses.update(loss.item(), batch_size)
        # record accuracy
        preds.append(y_preds.softmax(1).to('cpu').numpy())
        if CFG["gradient_accumulation_steps"] > 1:
            loss = loss / CFG["gradient_accumulation_steps"]
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if step % CFG["print_freq"] == 0 or step == (len(valid_loader)-1):
            LOGGER.info('EVAL(valid): [{0}/{1}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: now{loss.val:.4f}(avg{loss.avg:.4f}) '
                  .format(
                   step, len(valid_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(valid_loader)),
                   ))
    predictions = np.concatenate(preds)
    return losses.avg, predictions


def inference(model, states, test_loader, device):
    model.to(device)
    tk0 = tqdm(enumerate(test_loader), total=len(test_loader))
    probs = []
    for i, (images) in tk0:
        images = images.to(device)
        avg_preds = []
        for state in states:
            model.load_state_dict(state['model'])
            model.eval()
            with torch.no_grad():
                y_preds = model(images)
            avg_preds.append(y_preds.softmax(1).to('cpu').numpy())
        avg_preds = np.mean(avg_preds, axis=0)
        probs.append(avg_preds)
    probs = np.concatenate(probs)
    return probs

# %% [markdown]
# # Train loop

# %%
# ====================================================
# Train loop
# ====================================================
def train_loop(folds, fold):

    LOGGER.info(f"========== fold: {fold} training ==========")

    # ====================================================
    # loader
    # ====================================================
    trn_idx = folds[folds['fold'] != fold].index
    val_idx = folds[folds['fold'] == fold].index

    train_folds = folds.loc[trn_idx].reset_index(drop=True)
    valid_folds = folds.loc[val_idx].reset_index(drop=True)

    train_dataset = TrainDataset(train_folds, 
                                 transform=get_transforms(data='train'))
    valid_dataset = TrainDataset(valid_folds, 
                                 transform=get_transforms(data='valid'))

    train_loader = DataLoader(train_dataset, 
                              batch_size=CFG["batch_size"], 
                              shuffle=True, 
                              num_workers=CFG["num_workers"], pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, 
                              batch_size=CFG["batch_size"], 
                              shuffle=False, 
                              num_workers=CFG["num_workers"], pin_memory=True, drop_last=False)
    
    # ====================================================
    # scheduler 
    # ====================================================
    def get_scheduler(optimizer):
        if CFG["scheduler"]=='ReduceLROnPlateau':
            scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=CFG["factor"], patience=CFG["patience"], verbose=True, eps=CFG["eps"])
        elif CFG["scheduler"]=='CosineAnnealingLR':
            scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)
        elif CFG["scheduler"]=='CosineAnnealingWarmRestarts':
            scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=CFG["T_0"], T_mult=1, eta_min=CFG["min_lr"], last_epoch=-1)
        return scheduler

    # ====================================================
    # model & optimizer
    # ====================================================
    model = get_model(pretrained=True)
    
    model.to(device)

    optimizer = Adam(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
    scheduler = get_scheduler(optimizer)

    # ====================================================
    # apex
    # ====================================================
    if CFG["apex"]:
        model, optimizer = amp.initialize(model, optimizer, opt_level='O1', verbosity=0)

    # ====================================================
    # loop
    # ====================================================
    criterion = nn.CrossEntropyLoss()

    best_score = 0.
    best_loss = np.inf
    
    for epoch in range(CFG["epochs"]):
        
        start_time = time.time()
        
        # train
        avg_loss = train_fn(train_loader, model, criterion, optimizer, epoch, scheduler, device)

        # eval
        avg_val_loss, preds = valid_fn(valid_loader, model, criterion, device)
        valid_labels = valid_folds[CFG["target_col"]].values
        
        if isinstance(scheduler, ReduceLROnPlateau):
            scheduler.step(avg_val_loss)
        elif isinstance(scheduler, CosineAnnealingLR):
            scheduler.step()
        elif isinstance(scheduler, CosineAnnealingWarmRestarts):
            scheduler.step()

        # scoring
        score = get_score(valid_labels, preds.argmax(1))
        roc_auc = roc_auc_score(valid_labels, preds.argmax(1))
        f1 =  f1_score(valid_labels, preds.argmax(1))
        elapsed = time.time() - start_time

        LOGGER.info(f'Epoch {epoch+1} - avg_train_loss: {avg_loss:.4f}  avg_val_loss: {avg_val_loss:.4f}  time: {elapsed:.0f}s')
        LOGGER.info(f'Epoch {epoch+1} - Accuracy: {score}　  Roc_auc:{roc_auc}  F1:{f1}')
        if fold==0:
            wandb.log({"avg_train_loss": avg_loss, "avg_val_loss":avg_val_loss, "val_accuracy":score, "val_roc_auc":roc_auc, "val_f1":f1})

        if score > best_score:
            best_score = score
            LOGGER.info(f'Epoch {epoch+1} - Save Best Score: {best_score:.4f} Model')
            torch.save({'model': model.state_dict(), 
                        'preds': preds},
                        os.path.join(OUTPUT_DIR,f'{CFG["model_name"]}_fold{fold}_best.pth'))
            wandb.save(os.path.join(OUTPUT_DIR,f'{CFG["model_name"]}_fold{fold}_best.pth'))
    
    check_point = torch.load( os.path.join(OUTPUT_DIR,f'{CFG["model_name"]}_fold{fold}_best.pth'))
    valid_folds[[str(c) for c in range(CFG["target_size"])]] = check_point['preds']
    valid_folds['preds'] = check_point['preds'].argmax(1)

    return valid_folds

# %%
# ====================================================
# main
# ====================================================
def main():

    """
    Prepare: 1.train  2.test  3.submission  4.folds
    """

    def get_result(result_df):
        preds = result_df['preds'].values
        labels = result_df[CFG["target_col"]].values
        score = get_score(labels, preds)
        roc_auc = roc_auc_score(labels, preds)
        f1 =  f1_score(labels, preds)
        LOGGER.info(f'Accuracy: {score:<.5f}　  Roc_auc:{roc_auc:<.5f}  F1:{f1:<.5f}')

    if CFG["train"]:
        # train 
        oof_df = pd.DataFrame()
        for fold in range(CFG["n_fold"]):
            if fold in CFG["trn_fold"]:
                _oof_df = train_loop(folds, fold)
                oof_df = pd.concat([oof_df, _oof_df])
                LOGGER.info(f"========== fold: {fold} result ==========")
                get_result(_oof_df)
        # CV result
        LOGGER.info(f"========== CV ==========")
        get_result(oof_df)
        # save result
        oof_df.to_csv(OUTPUT_DIR+'oof_df.csv', index=False)
    
    if CFG["inference"]:
        # inference
        model = get_model(pretrained=True)
        states = [torch.load(OUTPUT_DIR+f'{CFG["model_name"]}_fold{fold}_best.pth') for fold in CFG["trn_fold"]]
        test_dataset = TestDataset(test, transform=get_transforms(data='valid'))
        test_loader = DataLoader(test_dataset, batch_size=CFG["batch_size"], shuffle=False, 
                                 num_workers=CFG["num_workers"], pin_memory=True)
        predictions = inference(model, states, test_loader, device)
        # submission
        test['label'] = predictions.argmax(1)
        test[['image_id', 'label']].to_csv(OUTPUT_DIR+'submission.csv', index=False)

# %% [markdown]
# # Train

# %%
if __name__ == '__main__':
    main()
# Out:
# ========== fold: 0 training ==========
# Epoch(train): [1][0/1500] Data 0.400 (0.400) Elapsed 0m 0s (remain 24m 16s) Loss: 0.6681(0.6681) Grad: 2.8369
# Epoch(train): [1][100/1500] Data 0.000 (0.004) Elapsed 0m 53s (remain 12m 27s) Loss: 0.4542(0.5451) Grad: 3.8390
# Epoch(train): [1][200/1500] Data 0.000 (0.002) Elapsed 1m 46s (remain 11m 30s) Loss: 0.1935(0.4585) Grad: 3.3922
# Epoch(train): [1][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 37s) Loss: 0.5989(0.4154) Grad: 10.6406
# Epoch(train): [1][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.2941(0.3861) Grad: 6.0061
# Epoch(train): [1][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 50s) Loss: 0.1925(0.3605) Grad: 3.9323
# Epoch(train): [1][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 57s) Loss: 0.1887(0.3345) Grad: 5.2410
# Epoch(train): [1][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.1751(0.3266) Grad: 2.7657
# Epoch(train): [1][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.1001(0.3151) Grad: 2.2265
# Epoch(train): [1][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.2188(0.3061) Grad: 3.4482
# Epoch(train): [1][1000/1500] Data 0.000 (0.001) Elapsed 8m 51s (remain 4m 24s) Loss: 0.3126(0.2960) Grad: 4.2408
# Epoch(train): [1][1100/1500] Data 0.000 (0.001) Elapsed 9m 44s (remain 3m 31s) Loss: 0.5843(0.2889) Grad: 6.7633
# Epoch(train): [1][1200/1500] Data 0.000 (0.001) Elapsed 10m 37s (remain 2m 38s) Loss: 0.5449(0.2784) Grad: 6.7807
# Epoch(train): [1][1300/1500] Data 0.000 (0.001) Elapsed 11m 30s (remain 1m 45s) Loss: 0.1531(0.2740) Grad: 3.4031
# Epoch(train): [1][1400/1500] Data 0.000 (0.001) Elapsed 12m 23s (remain 0m 52s) Loss: 0.1280(0.2668) Grad: 3.8145
# Epoch(train): [1][1499/1500] Data 0.000 (0.000) Elapsed 13m 15s (remain 0m 0s) Loss: 0.1210(0.2627) Grad: 2.4766
# EVAL(valid): [0/375] Data 0.373 (0.373) Elapsed 0m 0s (remain 3m 3s) Loss: now0.0585(avg0.0585)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0223(avg0.1469)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0362(avg0.1392)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now0.9061(avg0.1492)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.1392(avg0.1526)
# Epoch 1 - avg_train_loss: 0.2627  avg_val_loss: 0.1526  time: 840s
# Epoch 1 - Accuracy: 0.9396666666666667　  Roc_auc:0.9096111031197199  F1:0.9583812370659922
# Epoch 1 - Save Best Score: 0.9397 Model
# Epoch(train): [2][0/1500] Data 0.492 (0.492) Elapsed 0m 1s (remain 25m 39s) Loss: 0.0894(0.0894) Grad: 2.6480
# Epoch(train): [2][100/1500] Data 0.000 (0.005) Elapsed 0m 54s (remain 12m 28s) Loss: 0.0561(0.1696) Grad: 1.5588
# Epoch(train): [2][200/1500] Data 0.000 (0.003) Elapsed 1m 46s (remain 11m 31s) Loss: 0.0949(0.1642) Grad: 2.5301
# Epoch(train): [2][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 36s) Loss: 1.0384(0.1643) Grad: 8.1953
# Epoch(train): [2][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.0227(0.1616) Grad: 0.7698
# Epoch(train): [2][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 49s) Loss: 0.0120(0.1597) Grad: 0.2825
# Epoch(train): [2][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 56s) Loss: 0.1040(0.1593) Grad: 3.6506
# Epoch(train): [2][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.0379(0.1612) Grad: 1.4706
# Epoch(train): [2][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.1148(0.1614) Grad: 3.0767
# Epoch(train): [2][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 1.9397(0.1641) Grad: 25.5497
# Epoch(train): [2][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.1335(0.1640) Grad: 2.4465
# Epoch(train): [2][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0974(0.1639) Grad: 2.0979
# Epoch(train): [2][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0241(0.1626) Grad: 0.6357
# Epoch(train): [2][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0442(0.1608) Grad: 1.6812
# Epoch(train): [2][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.2438(0.1598) Grad: 3.8028
# Epoch(train): [2][1499/1500] Data 0.000 (0.001) Elapsed 13m 14s (remain 0m 0s) Loss: 0.4624(0.1592) Grad: 5.8675
# EVAL(valid): [0/375] Data 0.391 (0.391) Elapsed 0m 0s (remain 3m 10s) Loss: now0.0850(avg0.0850)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0058(avg0.1240)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0190(avg0.1156)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now0.5660(avg0.1248)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.1679(avg0.1267)
# Epoch 2 - avg_train_loss: 0.1592  avg_val_loss: 0.1267  time: 839s
# Epoch 2 - Accuracy: 0.9486666666666667　  Roc_auc:0.9326654915743302  F1:0.9639850327408793
# Epoch 2 - Save Best Score: 0.9487 Model
# Epoch(train): [3][0/1500] Data 0.517 (0.517) Elapsed 0m 1s (remain 26m 17s) Loss: 0.0836(0.0836) Grad: 2.1795
# Epoch(train): [3][100/1500] Data 0.000 (0.005) Elapsed 0m 54s (remain 12m 29s) Loss: 0.0605(0.1504) Grad: 1.4285
# Epoch(train): [3][200/1500] Data 0.000 (0.003) Elapsed 1m 47s (remain 11m 31s) Loss: 0.5188(0.1362) Grad: 6.3987
# Epoch(train): [3][300/1500] Data 0.000 (0.002) Elapsed 2m 40s (remain 10m 37s) Loss: 0.1355(0.1277) Grad: 4.0267
# Epoch(train): [3][400/1500] Data 0.000 (0.002) Elapsed 3m 33s (remain 9m 43s) Loss: 0.1519(0.1218) Grad: 5.6584
# Epoch(train): [3][500/1500] Data 0.000 (0.001) Elapsed 4m 26s (remain 8m 50s) Loss: 0.0188(0.1216) Grad: 0.7392
# Epoch(train): [3][600/1500] Data 0.000 (0.001) Elapsed 5m 19s (remain 7m 57s) Loss: 0.0946(0.1174) Grad: 3.3848
# Epoch(train): [3][700/1500] Data 0.000 (0.001) Elapsed 6m 12s (remain 7m 4s) Loss: 0.0477(0.1191) Grad: 1.5496
# Epoch(train): [3][800/1500] Data 0.000 (0.001) Elapsed 7m 5s (remain 6m 10s) Loss: 0.0440(0.1175) Grad: 2.2480
# Epoch(train): [3][900/1500] Data 0.000 (0.001) Elapsed 7m 58s (remain 5m 17s) Loss: 0.0359(0.1189) Grad: 1.3571
# Epoch(train): [3][1000/1500] Data 0.000 (0.001) Elapsed 8m 51s (remain 4m 24s) Loss: 0.0096(0.1175) Grad: 0.3833
# Epoch(train): [3][1100/1500] Data 0.000 (0.001) Elapsed 9m 44s (remain 3m 31s) Loss: 0.0853(0.1170) Grad: 2.4344
# Epoch(train): [3][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0463(0.1180) Grad: 1.8540
# Epoch(train): [3][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.1687(0.1198) Grad: 9.8397
# Epoch(train): [3][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0220(0.1204) Grad: 0.7290
# Epoch(train): [3][1499/1500] Data 0.000 (0.001) Elapsed 13m 15s (remain 0m 0s) Loss: 0.1869(0.1200) Grad: 5.0621
# EVAL(valid): [0/375] Data 0.376 (0.376) Elapsed 0m 0s (remain 3m 6s) Loss: now0.0381(avg0.0381)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0090(avg0.1099)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0590(avg0.1076)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now0.4553(avg0.1189)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.2190(avg0.1243)
# Epoch 3 - avg_train_loss: 0.1200  avg_val_loss: 0.1243  time: 840s
# Epoch 3 - Accuracy: 0.955　  Roc_auc:0.9504963727432967  F1:0.9679715302491104
# Epoch 3 - Save Best Score: 0.9550 Model
# Epoch(train): [4][0/1500] Data 0.508 (0.508) Elapsed 0m 1s (remain 26m 11s) Loss: 0.0378(0.0378) Grad: 1.2205
# Epoch(train): [4][100/1500] Data 0.000 (0.005) Elapsed 0m 54s (remain 12m 29s) Loss: 0.0309(0.0728) Grad: 2.1723
# Epoch(train): [4][200/1500] Data 0.000 (0.003) Elapsed 1m 47s (remain 11m 31s) Loss: 0.0434(0.0836) Grad: 1.8947
# Epoch(train): [4][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 37s) Loss: 0.0319(0.0822) Grad: 1.3344
# Epoch(train): [4][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.1244(0.0828) Grad: 6.5430
# Epoch(train): [4][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 50s) Loss: 0.0424(0.0836) Grad: 1.8575
# Epoch(train): [4][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 56s) Loss: 0.0045(0.0793) Grad: 0.2807
# Epoch(train): [4][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.0041(0.0781) Grad: 0.3802
# Epoch(train): [4][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0646(0.0782) Grad: 4.3042
# Epoch(train): [4][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0013(0.0801) Grad: 0.0568
# Epoch(train): [4][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0840(0.0803) Grad: 4.6207
# Epoch(train): [4][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0074(0.0801) Grad: 0.2864
# Epoch(train): [4][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0049(0.0804) Grad: 0.2094
# Epoch(train): [4][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0046(0.0809) Grad: 0.2573
# Epoch(train): [4][1400/1500] Data 0.000 (0.001) Elapsed 12m 21s (remain 0m 52s) Loss: 0.0730(0.0814) Grad: 3.2278
# Epoch(train): [4][1499/1500] Data 0.000 (0.001) Elapsed 13m 14s (remain 0m 0s) Loss: 0.3326(0.0820) Grad: 9.8705
# EVAL(valid): [0/375] Data 0.371 (0.371) Elapsed 0m 0s (remain 3m 3s) Loss: now0.0115(avg0.0115)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0017(avg0.1115)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0165(avg0.1019)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now0.8489(avg0.1112)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.0605(avg0.1240)
# Epoch 4 - avg_train_loss: 0.0820  avg_val_loss: 0.1240  time: 838s
# Epoch 4 - Accuracy: 0.957　  Roc_auc:0.9469023936244441  F1:0.9696541990119971
# Epoch 4 - Save Best Score: 0.9570 Model
# Epoch(train): [5][0/1500] Data 0.486 (0.486) Elapsed 0m 1s (remain 25m 45s) Loss: 0.0016(0.0016) Grad: 0.0670
# Epoch(train): [5][100/1500] Data 0.000 (0.005) Elapsed 0m 54s (remain 12m 29s) Loss: 0.0571(0.0281) Grad: 3.0104
# Epoch(train): [5][200/1500] Data 0.000 (0.003) Elapsed 1m 47s (remain 11m 31s) Loss: 0.0874(0.0593) Grad: 3.7629
# Epoch(train): [5][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 36s) Loss: 0.0485(0.0621) Grad: 2.4637
# Epoch(train): [5][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.0195(0.0609) Grad: 0.8021
# Epoch(train): [5][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 49s) Loss: 0.0114(0.0613) Grad: 0.8848
# Epoch(train): [5][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 56s) Loss: 0.0010(0.0591) Grad: 0.0785
# Epoch(train): [5][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.0009(0.0590) Grad: 0.0776
# Epoch(train): [5][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0609(0.0568) Grad: 3.0635
# Epoch(train): [5][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0047(0.0559) Grad: 0.2271
# Epoch(train): [5][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0045(0.0581) Grad: 0.2940
# Epoch(train): [5][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0154(0.0575) Grad: 0.8678
# Epoch(train): [5][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.3704(0.0569) Grad: 8.3785
# Epoch(train): [5][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0239(0.0573) Grad: 2.0352
# Epoch(train): [5][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0277(0.0567) Grad: 1.5889
# Epoch(train): [5][1499/1500] Data 0.000 (0.001) Elapsed 13m 14s (remain 0m 0s) Loss: 0.0331(0.0578) Grad: 2.6551
# EVAL(valid): [0/375] Data 0.367 (0.367) Elapsed 0m 0s (remain 3m 2s) Loss: now0.0023(avg0.0023)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0051(avg0.1356)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0198(avg0.1198)
# EVAL(valid): [300/375] Data 0.000 (0.001) Elapsed 0m 35s (remain 0m 8s) Loss: now0.6236(avg0.1312)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.0729(avg0.1434)
# Epoch 5 - avg_train_loss: 0.0578  avg_val_loss: 0.1434  time: 839s
# Epoch 5 - Accuracy: 0.9516666666666667　  Roc_auc:0.9431323653492322  F1:0.9657615112160567
# Epoch(train): [6][0/1500] Data 0.391 (0.391) Elapsed 0m 0s (remain 23m 8s) Loss: 0.0975(0.0975) Grad: 4.3029
# Epoch(train): [6][100/1500] Data 0.000 (0.004) Elapsed 0m 53s (remain 12m 26s) Loss: 0.0253(0.0264) Grad: 1.8992
# Epoch(train): [6][200/1500] Data 0.000 (0.002) Elapsed 1m 46s (remain 11m 30s) Loss: 0.0124(0.0328) Grad: 0.7815
# Epoch(train): [6][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 37s) Loss: 0.0070(0.0344) Grad: 0.4536
# Epoch(train): [6][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.0106(0.0364) Grad: 1.0888
# Epoch(train): [6][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 50s) Loss: 0.0008(0.0343) Grad: 0.0303
# Epoch(train): [6][600/1500] Data 0.000 (0.001) Elapsed 5m 19s (remain 7m 57s) Loss: 0.1289(0.0365) Grad: 8.4934
# Epoch(train): [6][700/1500] Data 0.000 (0.001) Elapsed 6m 12s (remain 7m 4s) Loss: 0.0058(0.0355) Grad: 0.3470
# Epoch(train): [6][800/1500] Data 0.000 (0.001) Elapsed 7m 5s (remain 6m 10s) Loss: 0.2076(0.0348) Grad: 9.4631
# Epoch(train): [6][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0048(0.0359) Grad: 0.2879
# Epoch(train): [6][1000/1500] Data 0.000 (0.001) Elapsed 8m 51s (remain 4m 24s) Loss: 0.0005(0.0356) Grad: 0.0220
# Epoch(train): [6][1100/1500] Data 0.000 (0.001) Elapsed 9m 44s (remain 3m 31s) Loss: 0.0025(0.0341) Grad: 0.1638
# Epoch(train): [6][1200/1500] Data 0.000 (0.001) Elapsed 10m 37s (remain 2m 38s) Loss: 0.0039(0.0338) Grad: 0.3972
# Epoch(train): [6][1300/1500] Data 0.000 (0.001) Elapsed 11m 30s (remain 1m 45s) Loss: 0.0292(0.0362) Grad: 3.7700
# Epoch(train): [6][1400/1500] Data 0.000 (0.001) Elapsed 12m 23s (remain 0m 52s) Loss: 0.0017(0.0357) Grad: 0.0905
# Epoch(train): [6][1499/1500] Data 0.000 (0.000) Elapsed 13m 15s (remain 0m 0s) Loss: 0.0001(0.0360) Grad: 0.0035
# EVAL(valid): [0/375] Data 0.364 (0.364) Elapsed 0m 0s (remain 3m 0s) Loss: now0.0016(avg0.0016)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0009(avg0.1172)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0011(avg0.1161)
# EVAL(valid): [300/375] Data 0.000 (0.001) Elapsed 0m 35s (remain 0m 8s) Loss: now0.7839(avg0.1292)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.0353(avg0.1397)
# Epoch 6 - avg_train_loss: 0.0360  avg_val_loss: 0.1397  time: 840s
# Epoch 6 - Accuracy: 0.96　  Roc_auc:0.9510261304180737  F1:0.9717514124293785
# Epoch 6 - Save Best Score: 0.9600 Model
# Epoch(train): [7][0/1500] Data 0.512 (0.512) Elapsed 0m 1s (remain 26m 20s) Loss: 0.0023(0.0023) Grad: 0.1115
# Epoch(train): [7][100/1500] Data 0.000 (0.005) Elapsed 0m 54s (remain 12m 28s) Loss: 0.0014(0.0279) Grad: 0.0941
# Epoch(train): [7][200/1500] Data 0.000 (0.003) Elapsed 1m 47s (remain 11m 32s) Loss: 0.0145(0.0219) Grad: 1.0959
# Epoch(train): [7][300/1500] Data 0.000 (0.002) Elapsed 2m 40s (remain 10m 37s) Loss: 0.0148(0.0192) Grad: 1.9240
# Epoch(train): [7][400/1500] Data 0.000 (0.001) Elapsed 3m 33s (remain 9m 43s) Loss: 0.0084(0.0197) Grad: 0.8326
# Epoch(train): [7][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 50s) Loss: 0.0010(0.0198) Grad: 0.0605
# Epoch(train): [7][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 57s) Loss: 0.0024(0.0204) Grad: 0.1990
# Epoch(train): [7][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.0222(0.0201) Grad: 2.2594
# Epoch(train): [7][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0023(0.0203) Grad: 0.2505
# Epoch(train): [7][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.3182(0.0223) Grad: 14.6351
# Epoch(train): [7][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0019(0.0220) Grad: 0.1289
# Epoch(train): [7][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0029(0.0219) Grad: 0.2438
# Epoch(train): [7][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0238(0.0229) Grad: 2.5558
# Epoch(train): [7][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0227(0.0230) Grad: 2.8370
# Epoch(train): [7][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0435(0.0230) Grad: 4.8152
# Epoch(train): [7][1499/1500] Data 0.000 (0.001) Elapsed 13m 15s (remain 0m 0s) Loss: 0.0010(0.0226) Grad: 0.0677
# EVAL(valid): [0/375] Data 0.391 (0.391) Elapsed 0m 0s (remain 3m 10s) Loss: now0.0037(avg0.0037)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0007(avg0.1375)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0006(avg0.1302)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now1.1643(avg0.1526)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.0404(avg0.1591)
# Epoch 7 - avg_train_loss: 0.0226  avg_val_loss: 0.1591  time: 839s
# Epoch 7 - Accuracy: 0.9563333333333334　  Roc_auc:0.9440941948864161  F1:0.9692704668074127
# Epoch(train): [8][0/1500] Data 0.391 (0.391) Elapsed 0m 0s (remain 23m 16s) Loss: 0.0006(0.0006) Grad: 0.0411
# Epoch(train): [8][100/1500] Data 0.000 (0.004) Elapsed 0m 54s (remain 12m 28s) Loss: 0.0701(0.0323) Grad: 6.5095
# Epoch(train): [8][200/1500] Data 0.000 (0.002) Elapsed 1m 47s (remain 11m 31s) Loss: 0.0002(0.0225) Grad: 0.0084
# Epoch(train): [8][300/1500] Data 0.000 (0.002) Elapsed 2m 40s (remain 10m 37s) Loss: 0.0017(0.0225) Grad: 0.1174
# Epoch(train): [8][400/1500] Data 0.000 (0.001) Elapsed 3m 33s (remain 9m 43s) Loss: 0.0001(0.0207) Grad: 0.0038
# Epoch(train): [8][500/1500] Data 0.000 (0.001) Elapsed 4m 26s (remain 8m 50s) Loss: 0.0169(0.0195) Grad: 1.5389
# Epoch(train): [8][600/1500] Data 0.000 (0.001) Elapsed 5m 19s (remain 7m 57s) Loss: 0.0040(0.0199) Grad: 0.4122
# Epoch(train): [8][700/1500] Data 0.000 (0.001) Elapsed 6m 12s (remain 7m 4s) Loss: 0.0001(0.0181) Grad: 0.0077
# Epoch(train): [8][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0023(0.0176) Grad: 0.1574
# Epoch(train): [8][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0070(0.0179) Grad: 0.6091
# Epoch(train): [8][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0003(0.0170) Grad: 0.0311
# Epoch(train): [8][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0008(0.0162) Grad: 0.0896
# Epoch(train): [8][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.1388(0.0159) Grad: 16.3789
# Epoch(train): [8][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0005(0.0163) Grad: 0.0445
# Epoch(train): [8][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0018(0.0163) Grad: 0.2182
# Epoch(train): [8][1499/1500] Data 0.000 (0.000) Elapsed 13m 15s (remain 0m 0s) Loss: 0.0002(0.0157) Grad: 0.0124
# EVAL(valid): [0/375] Data 0.368 (0.368) Elapsed 0m 0s (remain 3m 2s) Loss: now0.0008(avg0.0008)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0003(avg0.1467)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0005(avg0.1319)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now1.2776(avg0.1454)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.0276(avg0.1599)
# Epoch 8 - avg_train_loss: 0.0157  avg_val_loss: 0.1599  time: 839s
# Epoch 8 - Accuracy: 0.9553333333333334　  Roc_auc:0.9480612049920671  F1:0.9683364839319472
# Epoch(train): [9][0/1500] Data 0.379 (0.379) Elapsed 0m 0s (remain 23m 6s) Loss: 0.0011(0.0011) Grad: 0.1043
# Epoch(train): [9][100/1500] Data 0.000 (0.004) Elapsed 0m 53s (remain 12m 26s) Loss: 0.0004(0.0092) Grad: 0.0397
# Epoch(train): [9][200/1500] Data 0.000 (0.002) Elapsed 1m 46s (remain 11m 30s) Loss: 0.0010(0.0110) Grad: 0.0757
# Epoch(train): [9][300/1500] Data 0.000 (0.001) Elapsed 2m 39s (remain 10m 36s) Loss: 0.0000(0.0112) Grad: 0.0013
# Epoch(train): [9][400/1500] Data 0.000 (0.001) Elapsed 3m 32s (remain 9m 43s) Loss: 0.0024(0.0098) Grad: 0.2859
# Epoch(train): [9][500/1500] Data 0.000 (0.001) Elapsed 4m 25s (remain 8m 50s) Loss: 0.0001(0.0102) Grad: 0.0108
# Epoch(train): [9][600/1500] Data 0.000 (0.001) Elapsed 5m 18s (remain 7m 56s) Loss: 0.0155(0.0097) Grad: 1.9553
# Epoch(train): [9][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 3s) Loss: 0.0002(0.0089) Grad: 0.0159
# Epoch(train): [9][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0000(0.0091) Grad: 0.0034
# Epoch(train): [9][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0003(0.0097) Grad: 0.0353
# Epoch(train): [9][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0036(0.0093) Grad: 0.5905
# Epoch(train): [9][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0003(0.0094) Grad: 0.0239
# Epoch(train): [9][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0014(0.0094) Grad: 0.2235
# Epoch(train): [9][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0015(0.0092) Grad: 0.1649
# Epoch(train): [9][1400/1500] Data 0.000 (0.000) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0295(0.0092) Grad: 3.1789
# Epoch(train): [9][1499/1500] Data 0.000 (0.000) Elapsed 13m 15s (remain 0m 0s) Loss: 0.0005(0.0103) Grad: 0.0517
# EVAL(valid): [0/375] Data 0.381 (0.381) Elapsed 0m 0s (remain 3m 6s) Loss: now0.0006(avg0.0006)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0001(avg0.1419)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0046(avg0.1347)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now0.8308(avg0.1506)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.2044(avg0.1631)
# Epoch 9 - avg_train_loss: 0.0103  avg_val_loss: 0.1631  time: 839s
# Epoch 9 - Accuracy: 0.9536666666666667　  Roc_auc:0.947216920470867  F1:0.9671005917159763
# Epoch(train): [10][0/1500] Data 0.398 (0.398) Elapsed 0m 0s (remain 23m 24s) Loss: 0.0002(0.0002) Grad: 0.0207
# Epoch(train): [10][100/1500] Data 0.000 (0.004) Elapsed 0m 53s (remain 12m 27s) Loss: 0.0099(0.0064) Grad: 1.4448
# Epoch(train): [10][200/1500] Data 0.000 (0.002) Elapsed 1m 46s (remain 11m 31s) Loss: 0.0016(0.0101) Grad: 0.2296
# Epoch(train): [10][300/1500] Data 0.000 (0.002) Elapsed 2m 39s (remain 10m 37s) Loss: 0.0008(0.0092) Grad: 0.0611
# Epoch(train): [10][400/1500] Data 0.000 (0.001) Elapsed 3m 33s (remain 9m 43s) Loss: 0.0004(0.0092) Grad: 0.0634
# Epoch(train): [10][500/1500] Data 0.000 (0.001) Elapsed 4m 26s (remain 8m 50s) Loss: 0.0000(0.0091) Grad: 0.0019
# Epoch(train): [10][600/1500] Data 0.000 (0.001) Elapsed 5m 19s (remain 7m 57s) Loss: 0.0003(0.0084) Grad: 0.0202
# Epoch(train): [10][700/1500] Data 0.000 (0.001) Elapsed 6m 11s (remain 7m 4s) Loss: 0.0047(0.0084) Grad: 0.5368
# Epoch(train): [10][800/1500] Data 0.000 (0.001) Elapsed 7m 4s (remain 6m 10s) Loss: 0.0000(0.0078) Grad: 0.0035
# Epoch(train): [10][900/1500] Data 0.000 (0.001) Elapsed 7m 57s (remain 5m 17s) Loss: 0.0221(0.0077) Grad: 2.3626
# Epoch(train): [10][1000/1500] Data 0.000 (0.001) Elapsed 8m 50s (remain 4m 24s) Loss: 0.0005(0.0072) Grad: 0.0523
# Epoch(train): [10][1100/1500] Data 0.000 (0.001) Elapsed 9m 43s (remain 3m 31s) Loss: 0.0010(0.0074) Grad: 0.0966
# Epoch(train): [10][1200/1500] Data 0.000 (0.001) Elapsed 10m 36s (remain 2m 38s) Loss: 0.0004(0.0077) Grad: 0.0536
# Epoch(train): [10][1300/1500] Data 0.000 (0.001) Elapsed 11m 29s (remain 1m 45s) Loss: 0.0609(0.0078) Grad: 6.6449
# Epoch(train): [10][1400/1500] Data 0.000 (0.001) Elapsed 12m 22s (remain 0m 52s) Loss: 0.0007(0.0077) Grad: 0.0896
# Epoch(train): [10][1499/1500] Data 0.000 (0.000) Elapsed 13m 15s (remain 0m 0s) Loss: 0.0011(0.0079) Grad: 0.1247
# EVAL(valid): [0/375] Data 0.375 (0.375) Elapsed 0m 0s (remain 3m 3s) Loss: now0.0005(avg0.0005)
# EVAL(valid): [100/375] Data 0.000 (0.004) Elapsed 0m 12s (remain 0m 32s) Loss: now0.0001(avg0.1451)
# EVAL(valid): [200/375] Data 0.000 (0.002) Elapsed 0m 23s (remain 0m 20s) Loss: now0.0007(avg0.1360)
# EVAL(valid): [300/375] Data 0.000 (0.002) Elapsed 0m 35s (remain 0m 8s) Loss: now1.1267(avg0.1540)
# EVAL(valid): [374/375] Data 0.000 (0.001) Elapsed 0m 43s (remain 0m 0s) Loss: now0.1064(avg0.1660)
# Epoch 10 - avg_train_loss: 0.0079  avg_val_loss: 0.1660  time: 839s
# Epoch 10 - Accuracy: 0.956　  Roc_auc:0.947864759896861  F1:0.9688532326569136
# ========== fold: 0 result ==========
# Accuracy: 0.96000　  Roc_auc:0.95103  F1:0.97175
# ========== CV ==========
# Accuracy: 0.96000　  Roc_auc:0.95103  F1:0.97175

# %%
wandb.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 966<br/>Program ended successfully.
# VBox(children=(Label(value=' 109.12MB of 109.12MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# Find user logs for this run at: <code>/content/drive/My Drive/git/kaggle-vinbigdata-xray/working/wandb/run-20210327_041740-1sx5pcel/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/drive/My Drive/git/kaggle-vinbigdata-xray/working/wandb/run-20210327_041740-1sx5pcel/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>avg_train_loss</td><td>0.00787</td></tr><tr><td>avg_val_loss</td><td>0.16601</td></tr><tr><td>val_accuracy</td><td>0.956</td></tr><tr><td>val_roc_auc</td><td>0.94786</td></tr><tr><td>val_f1</td><td>0.96885</td></tr><tr><td>_runtime</td><td>8417</td></tr><tr><td>_timestamp</td><td>1616827081</td></tr><tr><td>_step</td><td>9</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>avg_train_loss</td><td>█▅▄▃▂▂▁▁▁▁</td></tr><tr><td>avg_val_loss</td><td>▆▁▁▁▄▄▇▇██</td></tr><tr><td>val_accuracy</td><td>▁▄▆▇▅█▇▆▆▇</td></tr><tr><td>val_roc_auc</td><td>▁▅█▇▇█▇▇▇▇</td></tr><tr><td>val_f1</td><td>▁▄▆▇▅█▇▆▆▆</td></tr><tr><td>_runtime</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>_timestamp</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>_step</td><td>▁▂▃▃▄▅▆▆▇█</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">clear-lion-12</strong>: <a href="https://wandb.ai/kami/vinbigdata-class-filter/runs/1sx5pcel" target="_blank">https://wandb.ai/kami/vinbigdata-class-filter/runs/1sx5pcel</a><br/>
